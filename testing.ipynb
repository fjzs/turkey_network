# %%
from class_city import City
import pandas as pd

# %%
df = pd.read_excel("./data/data.xlsx", sheet_name="fixed_link_cost", header=1, index_col=1)
df
# Out:
#         Name         1          2          3          4          5         6  \
# ID
# 1      ADANA  0.000000   0.389010   0.518652   1.343482   1.232207  0.089905
# 2   ADIYAMAN  0.396239   0.000000   2.468324   2.721588   3.867073  0.419446
# 3      AFYON  0.526807   2.461394   0.000000   4.225678   2.760791  0.109035
# 4       AĞRI  1.370385   2.725439   4.243571   0.000000   5.272821  0.691954
# 5     AMASYA  1.259937   3.881957   2.779220   5.285636   0.000000  0.319208
# ..       ...       ...        ...        ...        ...        ...       ...
# 77    YALOVA  3.994308  15.436157   3.431553  21.262447  14.156361  0.840081
# 78   KARABÜK  2.346417   9.646053   3.413783  12.867336   6.186737  0.332095
# 79     KİLİS  1.598554   4.095779  12.220302  18.868555  22.285826  2.225162
# 80  OSMANİYE  0.140752   1.183973   2.455342   5.037816   5.213004  0.435026
# 81     DÜZCE  1.728753   7.049222   2.082236   9.949837   5.504694  0.260762
#
# ...

# %%
for row in df.iterrows():
    origin_id = row[0]
    print(row[1].to_dict())
    break
# Out:
# {'Name': 'ADANA', 1: 0, 2: 329, 3: 573, 4: 961, 5: 613, 6: 490, 7: 558, 8: 1030, 9: 894, 10: 894, 11: 768, 12: 628, 13: 727, 14: 677, 15: 671, 16: 837, 17: 1094, 18: 576, 19: 575, 20: 768, 21: 518, 22: 1169, 23: 486, 24: 675, 25: 804, 26: 688, 27: 205, 28: 727, 29: 786, 30: 900, 31: 191, 32: 620, 33: 69, 34: 939, 35: 900, 36: 1007, 37: 690, 38: 333, 39: 1150, 40: 375, 41: 828, 42: 356, 43: 673, 44: 388, 45: 882, 46: 185, 47: 530, 48: 871, 49: 738, 50: 287, 51: 205, 52: 718, 53: 926, 54: 791, 55: 729, 56: 701, 57: 871, 58: 429, 59: 1071, 60: 499, 61: 852, 62: 621, 63: 342, 64: 689, 65: 895, 66: 473, 67: 754, 68: 265, 69: 809, 70: 290, 71: 475, 72: 614, 73: 711, 74: 769, 75: 1036, 76: 1064, 77: 893, 78: 701, 79: 242, 80: 85, 81: 722}
